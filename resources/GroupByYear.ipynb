# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


books = pd.read_csv("Books.csv")
books
# Out:
#      Unnamed: 0                                       Title  \
# 0             0                       To Kill a Mockingbird
# 1             1                                        1984
# 2             2                            The Great Gatsby
# 3             3       Harry Potter and the Sorcerer's Stone
# 4             4         The Hobbit, or There and Back Again
# ..          ...                                         ...
# 991         991  The Snows of Kilimanjaro and Other Stories
# 992         992                    The Street of Crocodiles
# 993         993                              Riddley Walker
# 994         994                          Play It As It Lays
# 995         995                             I'm Not Stiller
#
#                   Author  Rating Count  Review Count  Rating Value  N pag  \
# 0             Harper Lee       4629082         92962          4.28  324.0
# 1          George Orwell       3250211         72375          4.19  237.0
# 2    F. Scott Fitzgerald       3877685         68965          3.93  200.0
# 3           J.K. Rowling       7281482        115354          4.48  309.0
# 4         J.R.R. Tolkien       2973224         49547          4.28  366.0
# ..                   ...           ...           ...           ...    ...
# 991     Ernest Hemingway         33823          1453          3.87  144.0
# 992         Bruno Schulz          7034           599          4.13  160.0
# 993        Russell Hoban          7075           819          4.02  256.0
# 994          Joan Didion         29879          2278          3.88  231.0
# 995           Max Frisch          3985           187          4.06  377.0
#
#      1st Pub  series                                             Genres  \
# 0     1960.0       1              ['Classics', 'Fiction', 'Historical']
# 1     1949.0       0         ['Classics', 'Fiction', 'Science Fiction']
# 2     1925.0       0                ['Classics', 'Fiction', 'Academic']
# 3     1997.0       1              ['Fantasy', 'Fiction', 'Young Adult']
# 4     1937.0       1                 ['Fantasy', 'Classics', 'Fiction']
# ..       ...     ...                                                ...
# 991   1961.0       0           ['Fiction', 'Short Stories', 'Classics']
# 992   1933.0       0  ['Fiction', 'Short Stories', 'European Literat...
# 993   1980.0       0      ['Fiction', 'Science Fiction', 'Apocalyptic']
# 994   1970.0       0                  ['Fiction', 'Classics', 'Novels']
# 995   1954.0       0  ['Fiction', 'European Literature', 'German Lit...
#
#                                                 Awards  \
# 0    ['Pulitzer Prize for Fiction (1961)', 'Audie A...
# 1    ['Prometheus Hall of Fame Award (1984)', 'Locu...
# 2    ['Grammy Award Nominee for Best Spoken Word Al...
# 3    ["Mythopoeic Fantasy Award for Children's Lite...
# 4    ['Keith Barker Millennium Book Award', 'Books ...
# ..                                                 ...
# 991                                                NaN
# 992  ['Prix du Meilleur Livre Étranger for Roman (1...
# 993  ['Nebula Award Nominee for Best Novel (1982)',...
# 994                                                NaN
# 995                                                NaN
#
#                                                   Link
# 0    https://www.goodreads.com/book/show/2657.To_Ki...
# 1    https://www.goodreads.com/book/show/40961427-1984
# 2    https://www.goodreads.com/book/show/3.Harry_Po...
# 3    https://www.goodreads.com/book/show/4671.The_G...
# 4    https://www.goodreads.com/book/show/170448.Ani...
# ..                                                 ...
# 991  https://www.goodreads.com/book/show/244261.The...
# 992  https://www.goodreads.com/book/show/4645.The_S...
# 993  https://www.goodreads.com/book/show/428.Play_I...
# 994  https://www.goodreads.com/book/show/776573.Rid...
# 995  https://www.goodreads.com/book/show/265102.I_m...
#
# [996 rows x 12 columns]

# %%
max_rating = books['Rating Value'].max()
min_rating = books['Rating Value'].min()
range_of_ratings = max_rating - min_rating

books['minmax_norm_ratings'] = round(1 + 9*((books['Rating Value'] - min_rating)/range_of_ratings) , 3)

mean_rating = books['Rating Value'].mean()

books['mean_norm_ratings'] = round(1 + 9*((books['Rating Value'] - mean_rating)/range_of_ratings) , 3)

# %%
dr = books[["Title", "1st Pub", 'minmax_norm_ratings']]
dr
# Out:
#                                           Title  1st Pub  minmax_norm_ratings
# 0                         To Kill a Mockingbird   1960.0                7.705
# 1                                          1984   1949.0                7.161
# 2                              The Great Gatsby   1925.0                5.591
# 3         Harry Potter and the Sorcerer's Stone   1997.0                8.913
# 4           The Hobbit, or There and Back Again   1937.0                7.705
# ..                                          ...      ...                  ...
# 991  The Snows of Kilimanjaro and Other Stories   1961.0                5.228
# 992                    The Street of Crocodiles   1933.0                6.799
# 993                              Riddley Walker   1980.0                6.134
# 994                          Play It As It Lays   1970.0                5.289
# 995                             I'm Not Stiller   1954.0                6.376
#
# [996 rows x 3 columns]

# %%
#pd.crosstab(dr["1st Pub"], dr["minmax_norm_ratings"])

# %%
dyear = dr.groupby("1st Pub").agg({"minmax_norm_ratings": [lambda x: np.mean(x)]})
dyear.columns = ["Mean of norm ratings"]

dyear['publishing year'] = dyear.index

dyear = dyear.style.hide_index()

dyear
# Out:
# <style  type="text/css" >
# </style><table id="T_13b67776_54c8_11eb_a3ff_60f677e23b27" ><thead>    <tr>        <th class="col_heading level0 col0" >Mean of norm ratings</th>        <th class="col_heading level0 col1" >publishing year</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row0_col0" class="data row0 col0" >3.718000</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row0_col1" class="data row0 col1" >1900.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row1_col0" class="data row1 col0" >6.134333</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row1_col1" class="data row1 col1" >1901.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row2_col0" class="data row2 col0" >6.557000</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row2_col1" class="data row2 col1" >1902.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row3_col0" class="data row3 col0" >6.517000</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row3_col1" class="data row3 col1" >1903.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row4_col0" class="data row4 col0" >5.167500</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row4_col1" class="data row4 col1" >1904.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row5_col0" class="data row5 col0" >5.771500</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row5_col1" class="data row5 col1" >1905.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row6_col0" class="data row6 col0" >5.485000</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row6_col1" class="data row6 col1" >1906.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row7_col0" class="data row7 col0" >6.527000</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row7_col1" class="data row7 col1" >1908.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row8_col0" class="data row8 col0" >7.241667</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row8_col1" class="data row8 col1" >1909.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row9_col0" class="data row9 col0" >5.409250</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row9_col1" class="data row9 col1" >1910.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row10_col0" class="data row10 col0" >4.725000</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row10_col1" class="data row10 col1" >1911.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row11_col0" class="data row11 col0" >5.409000</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row11_col1" class="data row11 col1" >1912.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row12_col0" class="data row12 col0" >5.397400</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row12_col1" class="data row12 col1" >1913.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row13_col0" class="data row13 col0" >5.107000</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row13_col1" class="data row13 col1" >1914.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row14_col0" class="data row14 col0" >5.735600</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row14_col1" class="data row14 col1" >1915.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row15_col0" class="data row15 col0" >3.718000</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row15_col1" class="data row15 col1" >1916.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row16_col0" class="data row16 col0" >6.829000</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row16_col1" class="data row16 col1" >1917.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row17_col0" class="data row17 col0" >6.053667</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row17_col1" class="data row17 col1" >1918.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row18_col0" class="data row18 col0" >6.235000</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row18_col1" class="data row18 col1" >1919.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row19_col0" class="data row19 col0" >5.824750</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row19_col1" class="data row19 col1" >1920.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row20_col0" class="data row20 col0" >6.255000</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row20_col1" class="data row20 col1" >1921.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row21_col0" class="data row21 col0" >5.701500</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row21_col1" class="data row21 col1" >1922.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row22_col0" class="data row22 col0" >6.295333</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row22_col1" class="data row22 col1" >1923.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row23_col0" class="data row23 col0" >6.094000</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row23_col1" class="data row23 col1" >1924.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row24_col0" class="data row24 col0" >5.120778</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row24_col1" class="data row24 col1" >1925.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row25_col0" class="data row25 col0" >6.762400</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row25_col1" class="data row25 col1" >1926.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row26_col0" class="data row26 col0" >6.179625</td>
#                         <td id="T_13b67776_54c8_11eb_a3ff_60f677e23b27row26_col1" class="data row26 col1" >1927.000000</td>
#             </tr>
